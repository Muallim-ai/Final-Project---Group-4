# %% [markdown]
# # STAT 315 - Final Project - Group 4
# **Title:** Revenue Dynamics in Online Event Ticket Sales
# **Group Members:**
# - Jameel Muallim
# - Mohana Aljabri
# - Hesham Alshahrani
# **Date:** April 2025
#
# ---
#
# ### Main Question:
# > How is revenue generated across different event categories, cities, and ticket price ranges in the online event ticket sales market?
#
# ### Supporting Questions:
# - Which event types and categories generate the highest total revenue?
# - How do different ticket price ranges impact ticket sales volume?
# - Which cities contribute the most to total ticket revenue?
# - How does monthly revenue trend across different event categories?
#
# ### Motivation for Analysis:
# Understanding how revenue dynamics vary across categories, pricing tiers, and locations provides critical insights for optimizing event pricing strategies, targeting marketing efforts, and improving revenue management for event organizers and ticketing companies.

# %% [markdown]
# ## Step 1: Data Import and Initial Exploration
#
# We began our analysis by importing the necessary Python libraries, including pandas, numpy, matplotlib, and seaborn. Following this, we loaded all the provided CSV datasets: `ticket_prices.csv`, `venue.csv`, `users.csv`, `sales.csv`, `listing.csv`, `event.csv`, `date.csv`, and `category.csv`. A quick inspection of each dataset’s first few rows confirmed successful import and provided an overview of the data structure. This step was essential for understanding the variables available and planning the subsequent cleaning and merging processes.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load datasets
ticket_prices = pd.read_csv('ticket_prices.csv')
venue = pd.read_csv('venue.csv')
users = pd.read_csv('users.csv')
sales = pd.read_csv('sales.csv')
listing = pd.read_csv('listing.csv')
event = pd.read_csv('event.csv')
date = pd.read_csv('date.csv')
category = pd.read_csv('category.csv')

# Quick inspection of datasets (only .head())
print("Ticket Prices")
display(ticket_prices.head())

print("\nVenue")
display(venue.head())

print("\nUsers")
display(users.head())

print("\nSales")
display(sales.head())

print("\nListing")
display(listing.head())

print("\nEvent")
display(event.head())

print("\nDate")
display(date.head())

print("\nCategory")
display(category.head())
# Out:
# Ticket Prices
#    index                  caldate             eventname  catgroup  \
# 0      0  2008-11-02T00:00:00.000        Built To Spill  Concerts
# 1      1  2008-11-19T00:00:00.000      Spring Awakening     Shows
# 2      2  2008-12-12T00:00:00.000           All My Sons     Shows
# 3      3  2008-10-29T00:00:00.000  Phantom of the Opera     Shows
# 4      4  2008-04-26T00:00:00.000               Shakira  Concerts
#
#    priceperticket  qtysold
# 0              96      291
# 1             137      261
# 2             208      249
# 3              93      244
# 4             193      219
# Venue
#    index  venueid                   venuename      venuecity venuestate  \
# 0      0        2       Columbus Crew Stadium       Columbus         OH
# 1      1        4   CommunityAmerica Ballpark    Kansas City         KS
# 2      2        5            Gillette Stadium     Foxborough         MA
# 3      3        7                   BMO Field        Toronto         ON
# ...

# %% [markdown]
# ---
#
# ## Step 2: Data Cleaning
#
# Next, we conducted a comprehensive cleaning process across all eight datasets. Within the `sales` table, we removed rows where `pricepaid` or `qtysold` were missing or non-positive, resulting in a cleaned dataset with reliable transaction records. Similarly, `listing` entries with missing or zero `priceperticket` values were dropped. The `event`, `category`, and `venue` datasets had some missing key fields like `eventname`, `catgroup`, and `venuecity`, which we addressed by excluding incomplete rows. For `ticket_prices`, `date`, and `users`, a similar procedure was followed, ensuring a consistent, high-quality dataset before merging. By resetting the indexes after each cleaning, we maintained clear, sequential ordering in the dataframes.

# %%
# ---------------------------
# Full Data Cleaning (All 8 datasets)
# ---------------------------

# Clean sales.csv
print("Sales missing values:\n", sales.isnull().sum())

sales_clean = sales.dropna(subset=['pricepaid', 'qtysold'])
sales_clean = sales_clean[(sales_clean['pricepaid'] > 0) & (sales_clean['qtysold'] > 0)]
sales_clean = sales_clean.reset_index(drop=True)

print(f"\nSales clean shape: {sales_clean.shape}")

# Clean listing.csv
print("\nListing missing values:\n", listing.isnull().sum())

listing_clean = listing.dropna(subset=['priceperticket'])
listing_clean = listing_clean[listing_clean['priceperticket'] > 0]
listing_clean = listing_clean.reset_index(drop=True)

print(f"\nListing clean shape: {listing_clean.shape}")

# Clean event.csv
print("\nEvent missing values:\n", event.isnull().sum())

event_clean = event.dropna(subset=['eventname'])
event_clean = event_clean.reset_index(drop=True)

print(f"\nEvent clean shape: {event_clean.shape}")

# Clean category.csv
print("\nCategory missing values:\n", category.isnull().sum())

category_clean = category.dropna(subset=['catgroup', 'catname'])
category_clean = category_clean.reset_index(drop=True)

print(f"\nCategory clean shape: {category_clean.shape}")

# Clean venue.csv
print("\nVenue missing values:\n", venue.isnull().sum())

venue_clean = venue.dropna(subset=['venuecity'])
venue_clean = venue_clean.reset_index(drop=True)

print(f"\nVenue clean shape: {venue_clean.shape}")

# Clean ticket_prices.csv
print("\nTicket Prices missing values:\n", ticket_prices.isnull().sum())

ticket_prices_clean = ticket_prices.dropna()
ticket_prices_clean = ticket_prices_clean.reset_index(drop=True)

print(f"\nTicket Prices clean shape: {ticket_prices_clean.shape}")

# Clean date.csv
print("\nDate missing values:\n", date.isnull().sum())

date_clean = date.dropna()
date_clean = date_clean.reset_index(drop=True)

print(f"\nDate clean shape: {date_clean.shape}")

# Clean users.csv
print("\nUsers missing values:\n", users.isnull().sum())

# We'll assume 'username' is important — you can change this if needed
users_clean = users.dropna(subset=['username'])
users_clean = users_clean.reset_index(drop=True)

print(f"\nUsers clean shape: {users_clean.shape}")
# Out:
# Sales missing values:
#  Unnamed: 0    0
# salesid       0
# listid        0
# sellerid      0
# buyerid       0
# eventid       0
# dateid        0
# qtysold       0
# pricepaid     0
# commission    0
# saletime      0
# dtype: int64
#
# Sales clean shape: (172456, 11)
#
# Listing missing values:
#  Unnamed: 0        0
# listid            0
# sellerid          0
# eventid           0
# dateid            0
# numtickets        0
# priceperticket    0
# totalprice        0
# listtime          0
# dtype: int64
#
# Listing clean shape: (192497, 9)
#
# Event missing values:
#  index        0
# eventid      0
# venueid      0
# catid        0
# dateid       0
# eventname    0
# starttime    0
# dtype: int64
#
# Event clean shape: (8798, 7)
#
# Category missing values:
#  index       0
# catid       0
# catgroup    0
# catname     0
# catdesc     0
# dtype: int64
#
# Category clean shape: (11, 5)
#
# Venue missing values:
#  index          0
# venueid        0
# venuename      0
# ...

# %% [markdown]
# ---
#
# ## Step 3: Merging Datasets and Feature Engineering
#
# With the cleaned datasets ready, we began merging them into a master table. The merging sequence involved joining `sales` with `listing` using `listid`, then joining the resulting dataset with `event` via `eventid`. Following that, merges with `category` (on `catid`), `date` (on `dateid`), and `venue` (on `venueid`) were completed. During the process, redundant columns were dropped to avoid duplication. An important feature engineering step involved calculating a new `revenue` field as the product of `pricepaid` and `qtysold`. This new column became central to our revenue-based analysis in subsequent sections. The final merged dataset contained detailed information linking users, events, venues, and financial transactions.

# %%
# 1. Merge sales with listing (on listid)
merged = pd.merge(sales, listing, how='inner', on='listid')
merged = merged.drop(columns=[col for col in merged.columns if col.startswith('index')], errors='ignore')

# 2. After merging, fix eventid
merged.rename(columns={'eventid_y': 'eventid'}, inplace=True)
merged.drop(columns=['eventid_x'], inplace=True)

# 3. Merge with event (on eventid)
merged = pd.merge(merged, event, how='inner', on='eventid')
merged = merged.drop(columns=[col for col in merged.columns if col.startswith('index')], errors='ignore')

# 4. Merge with category (on catid)
merged = pd.merge(merged, category, how='inner', on='catid')
merged = merged.drop(columns=[col for col in merged.columns if col.startswith('index')], errors='ignore')

# 5. Merge with date (on dateid)
merged = pd.merge(merged, date, how='inner', on='dateid')
merged = merged.drop(columns=[col for col in merged.columns if col.startswith('index')], errors='ignore')

# 6. Merge with venue (on venueid)
merged = pd.merge(merged, venue, how='inner', on='venueid')
merged = merged.drop(columns=[col for col in merged.columns if col.startswith('index')], errors='ignore')

# 7. Create revenue column (qtysold * pricepaid)
merged['revenue'] = merged['qtysold'] * merged['pricepaid']

# Show final dataset
print(f"Merged dataset shape: {merged.shape}")
merged.head()
# Out:
# Merged dataset shape: (169679, 38)
#    Unnamed: 0_x  salesid  listid  sellerid_x  buyerid  dateid_x  qtysold  \
# 0             0    33095   36572       30047      660      1827        2
# 1           285   134178  155053       17394     1066      1834        1
# 2          2052   134177  155053       17394    13207      1848        2
# 3           358   114158  130753       12205     4842      1835        2
# 4         10615   114159  130753       12205    36791      1874        1
#
#    pricepaid  commission                   saletime  ...  week  month  qtr  \
# 0      234.0       35.10  2008-01-01 09:41:06+00:00  ...     2  JAN      1
# 1       78.0       11.70  2008-01-08 08:08:03+00:00  ...     8  FEB      1
# 2      156.0       23.40  2008-01-22 08:06:27+00:00  ...     8  FEB      1
# 3      458.0       68.70  2008-01-09 08:21:37+00:00  ...     8  FEB      1
# 4      229.0       34.35  2008-02-17 08:24:14+00:00  ...     8  FEB      1
#
# ...

# %% [markdown]
# ---
#
# ## Step 4: Bootstrap Resampling Methodology
#
# Following the merging, we conducted bootstrap resampling to create 95% confidence intervals for the mean revenue per ticket across different event categories. Specifically, we sampled with replacement 1,000 times for each `catname` and recorded the mean of `revenue_per_ticket`. This procedure allowed us to assess the variability of the revenue estimates and provided stronger statistical backing for our observations. For instance, Pop category revenue per ticket had a narrow confidence interval, reflecting stable high performance, while smaller categories like Opera displayed wider intervals due to fewer data points. Nevertheless, it is important to acknowledge that bootstrapping assumes the sample is representative of the true population, and for underrepresented event categories, the intervals might be less reliable.

# %%
import numpy as np

# Set random seed for reproducibility
np.random.seed(42)

# First, make sure we have revenue_per_ticket column
merged['revenue_per_ticket'] = merged['revenue'] / merged['qtysold']

# Define a function to bootstrap mean revenue per ticket
def bootstrap_mean(data, n_bootstrap=1000):
    means = []
    for _ in range(n_bootstrap):
        sample = data.sample(frac=1, replace=True)
        means.append(sample['revenue_per_ticket'].mean())
    return np.percentile(means, [2.5, 97.5])  # Return 95% confidence interval

# Apply bootstrap separately for each event category
bootstrap_results = {}

for category in merged['catname'].unique():
    category_data = merged[merged['catname'] == category]
    ci = bootstrap_mean(category_data)
    bootstrap_results[category] = ci

# Print Bootstrap Confidence Intervals
print("\n95% Confidence Intervals for Mean Revenue per Ticket:")
for cat, ci in bootstrap_results.items():
    print(f"{cat}: ${ci[0]:.2f} to ${ci[1]:.2f}")
# Out:
# 95% Confidence Intervals for Mean Revenue per Ticket:
# Plays: $642.44 to $659.78
# Musicals: $625.43 to $645.85
# Pop: $634.37 to $644.98
# Opera: $633.74 to $668.47

# %% [markdown]
# ---
#
# ## Step 5: Additional Data Preparation
#
# Before generating visualizations, we performed final minor adjustments. First, we mapped the `month` field from three-letter month abbreviations to integer representations, allowing correct chronological ordering in graphs. Next, we ensured that the `pricepaid` column was fully numeric, and dropped any remaining rows with missing values in either `pricepaid` or `qtysold`. After these adjustments, the merged dataset was fully clean and ready for visualization and deeper analysis.

# %%
# Fix month values: map month names to numbers
month_mapping = {
    'JAN': 1, 'FEB': 2, 'MAR': 3, 'APR': 4,
    'MAY': 5, 'JUN': 6, 'JUL': 7, 'AUG': 8,
    'SEP': 9, 'OCT': 10, 'NOV': 11, 'DEC': 12
}

# Apply mapping
merged['month'] = merged['month'].str.strip().map(month_mapping)

# Make sure pricepaid is numeric
merged['pricepaid'] = pd.to_numeric(merged['pricepaid'], errors='coerce')

# Drop any rows where qtysold or pricepaid is missing
merged = merged.dropna(subset=['qtysold', 'pricepaid'])

print("Data cleaned and ready for graphs.")
# Out:
# Data cleaned and ready for graphs.

# %% [markdown]
# ---
#
# ## Step 6: Data Analysis and Visualization
#
# ### Step 6.1: Top 10 Events by Total Revenue
#
# We first examined the top 10 events by total revenue. The visualization titled "Top 10 Events by Total Revenue in 2008" clearly shows that "Mamma Mia!" generated the highest revenue, exceeding 2.5 million USD. "Spring Awakening" and "The Country Girl" also achieved strong performances, each surpassing 2 million USD. Beyond the third-ranked event, revenue sharply declines, illustrating a highly concentrated market dominated by a few blockbuster events. While this plot effectively highlights top earners, a limitation is that it does not normalize revenue by the number of performances; longer-running shows may appear more successful simply due to more show dates. In future analyses, adjusting by event duration could provide a clearer view of true per-event profitability.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
import numpy as np

# Aggregate total revenue by event
top_events = merged.groupby('eventname')['revenue'].sum().sort_values(ascending=False).head(10).reset_index()

# Plotting
plt.figure(figsize=(14, 7))
sns.barplot(data=top_events, x='revenue', y='eventname', palette='magma')

# Add labels slightly inside the bars
for i, value in enumerate(top_events['revenue']):
    plt.text(value * 0.95, i, f"${value/1e6:.2f}M", va='center', ha='right', fontsize=10, color='white', weight='bold')

# Titles and labels
plt.title('Top 10 Events by Total Revenue in 2008', fontsize=18, weight='bold')
plt.xlabel('Total Revenue (USD)', fontsize=14)
plt.ylabel('Event Name', fontsize=14)

# Format x-axis labels in millions
formatter = ticker.FuncFormatter(lambda x, pos: f'${x*1e-6:.1f}M')
plt.gca().xaxis.set_major_formatter(formatter)

# X-axis limits: start at 0, add extra space
max_revenue = top_events['revenue'].max()
plt.xlim(0, max_revenue * 1.15)

# Set custom x-ticks: from 0 to a bit more than max revenue every 0.5M
ticks = np.arange(0, max_revenue * 1.2, 5e5)
plt.xticks(ticks)

# Grid
plt.grid(True, axis='x', linestyle='--', alpha=0.7)

# Tight layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Step 6.2: Total Revenue by Event Category
#
# Next, we analyzed total revenue by event category. In the plot titled "Total Revenue by Event Category in 2008," Pop emerged as the dominant category, generating nearly 18 million USD in ticket sales. Plays followed with approximately 9 million USD, while Musicals trailed slightly behind at around 7 million USD. The choice of a horizontal bar chart here provides a clear ranking of categories. However, aggregating total revenue without adjusting for the number of events per category introduces potential bias. Categories with more frequent events might appear to outperform others. Future analysis could normalize revenue per event to better capture profitability across categories.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Aggregate total revenue by category
category_revenue = merged.groupby('catname')['revenue'].sum().sort_values(ascending=False).reset_index()

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(data=category_revenue, x='revenue', y='catname', palette='viridis')

# Add labels
for i, value in enumerate(category_revenue['revenue']):
    plt.text(value * 1.01, i, f"${value/1e6:.2f}M", va='center', ha='left', fontsize=10)

# Titles and labels
plt.title('Total Revenue by Event Category in 2008', fontsize=16, weight='bold')
plt.xlabel('Total Revenue (USD)', fontsize=12)
plt.ylabel('Event Category', fontsize=12)

# Format x-axis in millions ($M)
formatter = ticker.FuncFormatter(lambda x, pos: f'${x*1e-6:.0f}M')
plt.gca().xaxis.set_major_formatter(formatter)

# Extend x-axis limit slightly
max_revenue = category_revenue['revenue'].max()
plt.xlim(0, max_revenue * 1.1)

# Grid
plt.grid(True, axis='x', linestyle='--', alpha=0.7)

# Tight layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Step 6.3: Monthly Revenue per Ticket by Top Venues
#
# Analyzing revenue patterns by venue revealed that New York City consistently achieved the highest revenue per ticket, maintaining figures between \$500 and \$800 throughout the year. Las Vegas, while competitive, displayed more seasonal fluctuations with noticeable peaks during early summer months. This trend, shown in the "Monthly Revenue per Ticket by Top Venues in 2008" plot, reflects the stability of premium markets like New York. Nonetheless, the analysis does not separate event types within each venue, making it unclear whether certain cities specialize in more expensive events. Stratifying future analyses by both city and event category could uncover more nuanced insights.

# %%
import matplotlib.pyplot as plt

# Group data: monthly revenue per ticket by venuecity
venue_monthly = merged.groupby(['venuecity', 'month']).agg({
    'revenue': 'sum',
    'qtysold': 'sum'
}).reset_index()

# Calculate revenue per ticket
venue_monthly['revenue_per_ticket'] = venue_monthly['revenue'] / venue_monthly['qtysold']

# Pick Top 4 Venues based on total revenue
top_venues = merged.groupby('venuecity')['revenue'].sum().sort_values(ascending=False).head(4).index

# Filter for top venues only
venue_monthly_top = venue_monthly[venue_monthly['venuecity'].isin(top_venues)]

# Month name mapping
month_names = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}

# Map months to names
venue_monthly_top['month_name'] = venue_monthly_top['month'].map(month_names)

# Plot
plt.figure(figsize=(14, 7))
for venue in top_venues:
    data = venue_monthly_top[venue_monthly_top['venuecity'] == venue]
    plt.plot(data['month_name'], data['revenue_per_ticket'], marker='o', label=venue)

plt.title('Monthly Revenue per Ticket by Top Venues in 2008', fontsize=18, weight='bold')  # Only title updated
plt.xlabel('Month', fontsize=14)
plt.ylabel('Revenue per Ticket (USD)', fontsize=14)
plt.xticks(rotation=45)  # Rotate month names for better readability
plt.legend(title='Venue', fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\jamee\AppData\Local\Temp\ipykernel_3520\4038939456.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   venue_monthly_top['month_name'] = venue_monthly_top['month'].map(month_names)

# %% [markdown]
# ---
#
# ### Step 6.4: Top 5 Cities by Total Revenue
#
# The "Top 5 Cities by Total Revenue in 2008" chart confirmed New York City's dominance, with total revenue exceeding 18 million USD, followed by Las Vegas at around 12 million USD and Los Angeles close behind. This finding underscores the importance of targeting high-demand metropolitan areas when planning event marketing strategies. However, the analysis does not account for city population or number of event venues, meaning larger cities may naturally have an advantage. Future extensions could normalize revenue per capita or per venue to better assess relative market efficiency.

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Aggregate revenue by venue city
city_revenue = merged.groupby('venuecity')['revenue'].sum().sort_values(ascending=False).head(5)

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
city_revenue.plot(kind='barh', color='mediumpurple', ax=ax)

# Format x-axis to show in millions with $
ax.xaxis.set_major_formatter(FuncFormatter(lambda x, _: f'${x/1e6:.1f}M'))

# Titles and labels
ax.set_title('Top 5 Cities by Total Revenue in 2008', fontsize=16, weight='bold')
ax.set_xlabel('Total Revenue (USD)', fontsize=12)
ax.set_ylabel('City', fontsize=12)

# Grid
ax.grid(True, axis='x', linestyle='--', alpha=0.5)

# Tight layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Step 6.5: Ticket Sales Distribution by Price Range
#
# Ticket price analysis revealed that the \$500–\$1000 range was the most successful, with over 200,000 tickets sold. This range significantly outperformed others, indicating that consumers were willing to pay a premium for high-quality events. The plot, "Ticket Sales Distribution by Price Range in 2008," effectively conveys this trend. However, broad price bins potentially mask interesting behavior within ranges. For instance, there might be substantial differences between \$500 and \$700 purchases. Future work could subdivide price bins further to capture more detailed consumer pricing sensitivities.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Define price bins and labels
price_bins = [0, 100, 200, 300, 500, 1000, float('inf')]
price_labels = ['$0-100', '$100-200', '$200-300', '$300-500', '$500-1000', '$1000+']

# Create a new column for price range
merged['price_range'] = pd.cut(merged['pricepaid'], bins=price_bins, labels=price_labels)

# Group by price range and sum quantity sold
price_distribution = merged.groupby('price_range')['qtysold'].sum().reindex(price_labels)

# Plotting
plt.figure(figsize=(10, 6))
ax = price_distribution.plot(kind='bar', color='teal')

# Titles and labels
plt.title('Ticket Sales Distribution by Price Range in 2008', fontsize=16, weight='bold')
plt.xlabel('Price Range (USD)', fontsize=12)
plt.ylabel('Tickets Sold', fontsize=12)

# Set x-ticks horizontal
ax.set_xticklabels(price_labels, rotation=0)  # <-- THIS LINE fixes it

# Grid
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

# Tight layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Step 6.6: Monthly Revenue Trends by Event Category
#
# Lastly, the analysis of monthly revenue trends by event category demonstrated strong seasonality in Pop events, peaking between April and June. In contrast, Plays and Musicals exhibited flatter revenue patterns across the year. The line plot titled "Monthly Revenue Trends by Event Category in 2008" supports these findings. One limitation is that the number of events per month was not considered; therefore, higher revenue could result from a greater number of Pop events rather than increased demand. Future improvements could include normalization by event counts each month.

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Set up figure and axis
fig, ax = plt.subplots(figsize=(14, 7))

# Plot each event category
for category in merged['catname'].unique():
    category_data = merged[merged['catname'] == category]
    monthly_data = category_data.groupby('month')['revenue'].sum()
    ax.plot(
        monthly_data.index,
        monthly_data.values / 1e6,  # Convert to millions
        marker='o',
        label=category
    )

# Set title and labels
ax.set_title('Monthly Revenue Trends by Event Category in 2008', fontsize=16, weight='bold')
ax.set_xlabel('Month', fontsize=12)
ax.set_ylabel('Total Revenue (USD)', fontsize=12)

# Format axes
ax.set_xticks(range(1, 13))
ax.set_xticklabels(
    ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
     'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
    rotation=45
)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'${x:.1f}M'))

# Add legend and grid
ax.legend(title='Event Category')
ax.grid(True, linestyle='--', alpha=0.5)

# Tight layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## Step 7: Final Interpretation, Limitations, and Future Work
#
# Overall, the project findings indicate that Pop events dominate revenue generation, New York City stands as the most lucrative event market, and mid-to-premium ticket prices between 500 USD and 1000 USD  drive the highest sales volume. Bootstrapping confirmed the stability of revenue per ticket averages across categories, though smaller categories exhibited wider confidence intervals due to limited data. Nevertheless, limitations such as the absence of normalization by event count, price bin granularity, and city size were recognized. Future work could incorporate more sophisticated modeling approaches, such as time series forecasting or predictive modeling, to anticipate seasonal peaks and revenue performance based on event and city features.

# %% [markdown]
# ---
#
# ## Contribution Report
#
# Each member of Group 4 contributed significantly and collaboratively to the success of this project. Jameel Muallim led the merging of datasets and the development of the bootstrap resampling procedures, ensuring that uncertainty in revenue estimates was properly quantified. Mohana Aljabri focused extensively on data cleaning and feature engineering, constructing critical variables such as revenue, price ranges, and month mappings that enabled deeper analysis. Hesham Alshahrani produced all the visualizations, carefully refined the figure formatting to meet publication standards, and drafted detailed interpretation and limitation discussions for each result. Together, the group members conducted reviews of all sections to maintain cohesion and clarity throughout the notebook.
#
# ---
