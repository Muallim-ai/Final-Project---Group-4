# %% [markdown]
# # Final Project - Group 4: Revenue Dynamics in Online Event Ticket Sales
#
# ## 1. Defining the Question(s)
# - Main question
# - Supporting questions
# - Motivation for analysis
#
# ## 2. Data Collection
# - Dataset source
# - Feature descriptions
# - Context and background
#
# ## 3. Data Cleaning and Preparation
# - Data quality issues and resolutions
# - Feature engineering steps
# - Handling missing values
#
# ## 4. Data Analysis
# - Visualizations
# - Resampling (Bootstrap, Cross-Validation)
# - Statistical modeling
#
# ## 5. Interpretation and Reporting
# - Key findings
# - Insights and implications
# - Limitations and future directions

# %% [markdown]
# ## 1. Defining the Question(s)
#
# Our project investigates revenue generation in the online event ticket sales market.
#
# **Main Question:**
# - Which event groupings and market segments generate the highest total revenue?
#
# **Supporting Questions:**
# - How do pricing tiers influence quantity sold and total revenue?
# - Which cities contribute the most to overall sales?
# - Which specific event types generate the highest revenue per ticket?
#
# **Motivation:**
# Understanding these revenue dynamics can support better pricing strategies and marketing decisions for event organizers and ticketing companies.

# %% [markdown]
# ## 2. Data Collection
#
# **Dataset Source:**
# - The datasets were originally obtained from DataCamp’s open datasets collection.
#
# **Dataset Description:**
# We are working with a relational database structure consisting of multiple files:
# - `ticket_prices.csv`: Contains ticket price and quantity sold information.
# - `venue.csv`: Contains details about event venues (city, state, etc.).
# - `users.csv`: Information about users/customers.
# - `sales.csv`: Sales transaction data.
# - `listing.csv`: Listing details connecting events and sales.
# - `event.csv`: Event metadata (event names, descriptions).
# - `date.csv`: Dates associated with events and sales.
# - `category.csv`: Event category hierarchy (group, name, description).
#
# **Context:**
# - Events occurred across major U.S. cities.
# - The files need to be merged carefully based on key fields (e.g., event ID, listing ID) to reconstruct full transactions.
# - Data covers various event categories, pricing tiers, venue locations, and ticket sales.

# %% [markdown]
# ## 3. Data Cleaning and Preparation

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load datasets
ticket_prices = pd.read_csv('ticket_prices.csv')
venue = pd.read_csv('venue.csv')
users = pd.read_csv('users.csv')
sales = pd.read_csv('sales.csv')
listing = pd.read_csv('listing.csv')
event = pd.read_csv('event.csv')
date = pd.read_csv('date.csv')
category = pd.read_csv('category.csv')

# Quick inspection of datasets (only .head())
print("Ticket Prices")
display(ticket_prices.head())

print("\nVenue")
display(venue.head())

print("\nUsers")
display(users.head())

print("\nSales")
display(sales.head())

print("\nListing")
display(listing.head())

print("\nEvent")
display(event.head())

print("\nDate")
display(date.head())

print("\nCategory")
display(category.head())
# Out:
# Ticket Prices
#    index                  caldate             eventname  catgroup  \
# 0      0  2008-11-02T00:00:00.000        Built To Spill  Concerts
# 1      1  2008-11-19T00:00:00.000      Spring Awakening     Shows
# 2      2  2008-12-12T00:00:00.000           All My Sons     Shows
# 3      3  2008-10-29T00:00:00.000  Phantom of the Opera     Shows
# 4      4  2008-04-26T00:00:00.000               Shakira  Concerts
#
#    priceperticket  qtysold
# 0              96      291
# 1             137      261
# 2             208      249
# 3              93      244
# 4             193      219
# Venue
#    index  venueid                   venuename      venuecity venuestate  \
# 0      0        2       Columbus Crew Stadium       Columbus         OH
# 1      1        4   CommunityAmerica Ballpark    Kansas City         KS
# 2      2        5            Gillette Stadium     Foxborough         MA
# 3      3        7                   BMO Field        Toronto         ON
# ...

# %%
# ---------------------------
# Full Data Cleaning (All 8 datasets)
# ---------------------------

# Clean sales.csv
print("Sales missing values:\n", sales.isnull().sum())

sales_clean = sales.dropna(subset=['pricepaid', 'qtysold'])
sales_clean = sales_clean[(sales_clean['pricepaid'] > 0) & (sales_clean['qtysold'] > 0)]
sales_clean = sales_clean.reset_index(drop=True)

print(f"\nSales clean shape: {sales_clean.shape}")

# Clean listing.csv
print("\nListing missing values:\n", listing.isnull().sum())

listing_clean = listing.dropna(subset=['priceperticket'])
listing_clean = listing_clean[listing_clean['priceperticket'] > 0]
listing_clean = listing_clean.reset_index(drop=True)

print(f"\nListing clean shape: {listing_clean.shape}")

# Clean event.csv
print("\nEvent missing values:\n", event.isnull().sum())

event_clean = event.dropna(subset=['eventname'])
event_clean = event_clean.reset_index(drop=True)

print(f"\nEvent clean shape: {event_clean.shape}")

# Clean category.csv
print("\nCategory missing values:\n", category.isnull().sum())

category_clean = category.dropna(subset=['catgroup', 'catname'])
category_clean = category_clean.reset_index(drop=True)

print(f"\nCategory clean shape: {category_clean.shape}")

# Clean venue.csv
print("\nVenue missing values:\n", venue.isnull().sum())

venue_clean = venue.dropna(subset=['venuecity'])
venue_clean = venue_clean.reset_index(drop=True)

print(f"\nVenue clean shape: {venue_clean.shape}")

# Clean ticket_prices.csv
print("\nTicket Prices missing values:\n", ticket_prices.isnull().sum())

ticket_prices_clean = ticket_prices.dropna()
ticket_prices_clean = ticket_prices_clean.reset_index(drop=True)

print(f"\nTicket Prices clean shape: {ticket_prices_clean.shape}")

# Clean date.csv
print("\nDate missing values:\n", date.isnull().sum())

date_clean = date.dropna()
date_clean = date_clean.reset_index(drop=True)

print(f"\nDate clean shape: {date_clean.shape}")

# Clean users.csv
print("\nUsers missing values:\n", users.isnull().sum())

# We'll assume 'username' is important — you can change this if needed
users_clean = users.dropna(subset=['username'])
users_clean = users_clean.reset_index(drop=True)

print(f"\nUsers clean shape: {users_clean.shape}")
# Out:
# Sales missing values:
#  index         0
# salesid       0
# listid        0
# sellerid      0
# buyerid       0
# eventid       0
# dateid        0
# qtysold       0
# pricepaid     0
# commission    0
# saletime      0
# dtype: int64
#
# Sales clean shape: (10000, 11)
#
# Listing missing values:
#  index             0
# listid            0
# sellerid          0
# eventid           0
# dateid            0
# numtickets        0
# priceperticket    0
# totalprice        0
# listtime          0
# dtype: int64
#
# Listing clean shape: (12500, 9)
#
# Event missing values:
#  index        0
# eventid      0
# venueid      0
# catid        0
# dateid       0
# eventname    0
# starttime    0
# dtype: int64
#
# Event clean shape: (8798, 7)
#
# Category missing values:
#  index       0
# catid       0
# catgroup    0
# catname     0
# catdesc     0
# dtype: int64
#
# Category clean shape: (11, 5)
#
# Venue missing values:
#  index          0
# venueid        0
# venuename      0
# ...

# %%
# 1. Merge sales with listing (on listid)
merged = pd.merge(sales, listing, how='inner', on='listid')

# 2. After merging, fix eventid
# Let's assume we keep eventid_y (from listing) and rename it
merged.rename(columns={'eventid_y': 'eventid'}, inplace=True)

# Optionally you can drop eventid_x (from sales) if you want
merged.drop(columns=['eventid_x'], inplace=True)

# 3. Now Merge with event (on eventid)
merged = pd.merge(merged, event, how='inner', on='eventid')

# 4. Merge with category (on catid)
merged = pd.merge(merged, category, how='inner', on='catid')

# 5. Merge with date (on dateid)
merged = pd.merge(merged, date, how='inner', on='dateid')

# 6. Merge with venue (on venueid)
merged = pd.merge(merged, venue, how='inner', on='venueid')

# 7. Create revenue column (qtysold * pricepaid)
merged['revenue'] = merged['qtysold'] * merged['pricepaid']

# Show final dataset
print(f"Merged dataset shape: {merged.shape}")
merged.head()
# Out:
# Merged dataset shape: (8136, 42)
#    index_x  salesid  listid  sellerid_x  buyerid  dateid_x  qtysold  \
# 0        0    97197  110942       43282      515      1827        2
# 1        6    97198  110942       43282     1532      1828        1
# 2      756    92086  105081       15369     3069      1834        2
# 3      875     3142    3365       32175     7198      1838        1
# 4      901    83503   95235       38408     8183      1838        1
#
#    pricepaid  commission                 saletime  ...  month  qtr  year  \
# 0        708      106.20  2008-01-01T02:30:52.000  ...  JAN      1  2008
# 1        354       53.10  2008-01-02T02:31:12.000  ...  JAN      1  2008
# 2        672      100.80  2008-01-08T07:56:33.000  ...  JAN      1  2008
# 3        233       34.95  2008-01-12T04:27:41.000  ...  JAN      1  2008
# 4        302       45.30  2008-01-12T10:09:56.000  ...  JAN      1  2008
#
#    holiday  index_y      venuename  venuecity venuestate  venueseats  revenue
# ...

# %%
import numpy as np

# Set random seed for reproducibility
np.random.seed(42)

# First, make sure we have revenue_per_ticket column
merged['revenue_per_ticket'] = merged['revenue'] / merged['qtysold']

# Define a function to bootstrap mean revenue per ticket
def bootstrap_mean(data, n_bootstrap=1000):
    means = []
    for _ in range(n_bootstrap):
        sample = data.sample(frac=1, replace=True)
        means.append(sample['revenue_per_ticket'].mean())
    return np.percentile(means, [2.5, 97.5])  # Return 95% confidence interval

# Apply bootstrap separately for each event category
bootstrap_results = {}

for category in merged['catname'].unique():
    category_data = merged[merged['catname'] == category]
    ci = bootstrap_mean(category_data)
    bootstrap_results[category] = ci

# Print Bootstrap Confidence Intervals
print("\n95% Confidence Intervals for Mean Revenue per Ticket:")
for cat, ci in bootstrap_results.items():
    print(f"{cat}: ${ci[0]:.2f} to ${ci[1]:.2f}")
# Out:
# 95% Confidence Intervals for Mean Revenue per Ticket:
# Pop: $617.59 to $672.34
# Musicals: $543.81 to $627.72
# Plays: $585.48 to $659.23
# Opera: $546.49 to $678.83

# %%
# Fix month values: map month names to numbers
month_mapping = {
    'JAN': 1, 'FEB': 2, 'MAR': 3, 'APR': 4,
    'MAY': 5, 'JUN': 6, 'JUL': 7, 'AUG': 8,
    'SEP': 9, 'OCT': 10, 'NOV': 11, 'DEC': 12
}

# Apply mapping
merged['month'] = merged['month'].str.strip().map(month_mapping)

# Make sure pricepaid is numeric
merged['pricepaid'] = pd.to_numeric(merged['pricepaid'], errors='coerce')

# Drop any rows where qtysold or pricepaid is missing
merged = merged.dropna(subset=['qtysold', 'pricepaid'])

print("Data cleaned and ready for graphs.")
# Out:
# Data cleaned and ready for graphs.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Aggregate total revenue by event
top_events = merged.groupby('eventname')['revenue'].sum().sort_values(ascending=False).head(10).reset_index()

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(data=top_events, x='revenue', y='eventname', palette='magma')

# Add labels to bars
for i, value in enumerate(top_events['revenue']):
    plt.text(value, i, f"${value/1e3:.0f}K", va='center', ha='left')

# Titles and labels
plt.title('Top 10 Events by Total Revenue', fontsize=16, weight='bold')
plt.xlabel('Total Revenue (USD)', fontsize=12)
plt.ylabel('Event Name', fontsize=12)

# Grid
plt.grid(True, axis='x', linestyle='--', alpha=0.7)

# Tight layout
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Aggregate total revenue by category
category_revenue = merged.groupby('catname')['revenue'].sum().sort_values(ascending=False).reset_index()

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(data=category_revenue, x='revenue', y='catname', palette='viridis')

# Add labels
for i, value in enumerate(category_revenue['revenue']):
    plt.text(value, i, f"${value/1e6:.2f}M", va='center', ha='left')

# Titles and labels
plt.title('Total Revenue by Event Category', fontsize=16, weight='bold')
plt.xlabel('Total Revenue (USD)')
plt.ylabel('Event Category')
plt.grid(True, axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate monthly revenue per ticket sold
monthly_revenue_per_ticket = (
    merged.groupby(['month', 'catname'])
    .apply(lambda df: df['revenue'].sum() / df['qtysold'].sum())
    .reset_index(name='revenue_per_ticket')
)

# Plotting
plt.figure(figsize=(12, 6))
sns.lineplot(
    data=monthly_revenue_per_ticket,
    x='month',
    y='revenue_per_ticket',
    hue='catname',
    marker='o',
    palette='tab10'  # Colorful palette
)

# Titles and labels
plt.title('Monthly Revenue per Ticket by Event Category', fontsize=16, weight='bold')
plt.xlabel('Month', fontsize=12)
plt.ylabel('Revenue per Ticket (USD)', fontsize=12)

# Grid and legend
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(title='Event Category')

# Tight layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Aggregate revenue by venue city
city_revenue = merged.groupby('venuecity')['revenue'].sum().sort_values(ascending=False).head(5)

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
city_revenue.plot(kind='barh', color='mediumpurple', ax=ax)

# Format x-axis to show in millions with $
ax.xaxis.set_major_formatter(FuncFormatter(lambda x, _: f'${x/1e6:.1f}M'))

# Titles and labels
ax.set_title('Top 5 Cities by Total Revenue', fontsize=16, weight='bold')
ax.set_xlabel('Total Revenue (USD)', fontsize=12)
ax.set_ylabel('City', fontsize=12)

# Grid
ax.grid(True, axis='x', linestyle='--', alpha=0.5)

# Tight layout
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Define price bins and labels
price_bins = [0, 100, 200, 300, 500, 1000, float('inf')]
price_labels = ['< $100', '$100-200', '$200-300', '$300-500', '$500-1000', '$1000+']

# Create a new column for price range
merged['price_range'] = pd.cut(merged['pricepaid'], bins=price_bins, labels=price_labels)

# Group by price range and sum quantity sold
price_distribution = merged.groupby('price_range')['qtysold'].sum().reindex(price_labels)

# Plotting
plt.figure(figsize=(10, 6))
price_distribution.plot(kind='bar', color='teal')

# Titles and labels
plt.title('Ticket Sales Distribution by Price Range', fontsize=16, weight='bold')
plt.xlabel('Price Range (USD)', fontsize=12)
plt.ylabel('Tickets Sold', fontsize=12)

# Grid
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

# Tight layout
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Aggregate total revenue and quantity sold per event category
efficiency = merged.groupby('catname').agg({
    'revenue': 'sum',
    'qtysold': 'sum'
}).reset_index()

# Calculate revenue per ticket
efficiency['revenue_per_ticket'] = efficiency['revenue'] / efficiency['qtysold']

# Sort by revenue_per_ticket descending
efficiency = efficiency.sort_values(by='revenue_per_ticket', ascending=False)

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(data=efficiency, x='revenue_per_ticket', y='catname', palette='crest')

# Add labels to bars
for i, v in enumerate(efficiency['revenue_per_ticket']):
    plt.text(v + 5, i, f"${v:.2f}", va='center')

# Titles and labels
plt.title('Revenue Efficiency by Event Category', fontsize=16, weight='bold')
plt.xlabel('Revenue per Ticket (USD)', fontsize=12)
plt.ylabel('Event Category', fontsize=12)

# Grid
plt.grid(True, axis='x', linestyle='--', alpha=0.5)

# Tight layout
plt.tight_layout()
plt.show()

# %% [markdown]
# p
